# %%
from preprocess import *

# %%
import numpy as np
print(np.log(4))
# Out:
# 1.3862943611198906

# %%
training_df.head(10)
# Out:
#                                               review  sentiment  \
# 0                              Size, Size, ans Size.          1
# 1       Excellent quality, speedy printing, low cost          1
# 2                    Cheap, good quality, small size          1
# 3  Attractive design, satisfying features, the ba...          1
# 4  Pretty much has every feature you could possib...          1
# 5            Ease of use, small size and reliability          1
# 6                           cheap,good print quality          1
# 7                                  takes clear shots          1
# 8                   Small, Light, Stylish, backlight          1
# 9  Absolutely Outstanding Photo Printing Results....          1
#
#                                       cleaned_review  x1  x2  x3  x4  x5  \
# 0                                  size size an size   0   0   0   0   0
# 1         excellent quality speedy printing low cost   2   0   0   0   0
# ...

# %%
training_df.tail(5)
# Out:
#                                                   review  sentiment  \
# 31995  small memory stick included, so you will need ...          0
# 31996      Bulky.  #13; #10;Not many bells and whistles.          0
# 31997                  Battery life. Awkward phone book.          0
# 31998     Low talk time, antenna breaks easier than most          0
# 31999  CompactFlash incompatibility, poor download so...          0
#
#                                           cleaned_review  x1  x2  x3  x4  x5  \
# 31995           small memory stick included you need buy   0   0   0   1   0
# 31996                             bulkymany bell whistle   0   0   0   0   0
# 31997                     battery lifeawkward phone book   0   0   0   0   0
# 31998                 low talk time antenna break easier   1   1   0   0   0
# 31999  compactflash incompatibility poor download sof...   0   3   0   0   0
#
#              x6
# 31995  1.945910
# 31996  1.098612
# 31997  1.386294
# 31998  1.791759
# ...

# %%
test_df.head(5)
# Out:
#                                               review  sentiment  \
# 0  Strong flash, direct TV connection, Free photo...          1
# 1  Light weight, "cool factor", easy user interfa...          1
# 2  Easy to read display, lots of interesting feat...          1
# 3  Thin, great sounding, extra features like vide...          1
# 4  Great quality, inexpensive, easy to install, c...          1
#
#                                       cleaned_review  x1  x2  x3  x4  x5  \
# 0  strong flash direct tv connection free photo e...   2   0   0   0   0
# 1  light weight cool factor easy user interface s...   2   0   0   0   0
# 2          easy read display lot interesting feature   2   0   0   0   0
# 3  thin great sounding extra feature like video c...   2   0   0   0   0
# 4  great quality inexpensive easy install cool pr...   5   0   0   0   0
#
#          x6
# 0  2.484907
# 1  2.197225
# 2  1.791759
# 3  2.197225
# 4  2.397895

# %%
test_df.tail(5)
# Out:
#                                                  review  sentiment  \
# 7995         No focus or flash control.  No AC adapter.          0
# 7996               Fold up tray durability questionable          0
# 7997                               Needs linux drivers.          0
# 7998                                            nothing          0
# 7999  Camera is awful, and menus need serious redesi...          0
#
#                                   cleaned_review  x1  x2  x3  x4  x5        x6
# 7995               focus flash controlac adapter   0   0   0   0   0  1.386294
# 7996           fold tray durability questionable   0   1   0   0   0  1.386294
# 7997                           need linux driver   0   0   0   0   0  1.098612
# 7998                                     nothing   0   0   0   0   0  0.000000
# 7999  camera awful menu need serious redesigning   0   1   0   0   0  1.791759

# %%
import re

alphabet_pattern = re.compile(r'[a-z!]+')
alphabet_pattern.findall(',')
# Out:
# []

# %%
from nltk.corpus import stopwords

en_stopwords = stopwords.words('english')
print(en_stopwords)
used_pronouns = ['i', 'me', 'you']
for value in used_pronouns: en_stopwords.remove(value)
print(en_stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
'us' in en_stopwords
# Out:
# False

# %%
lst = ['excellent', 'cheap', 'good', 'quality', 'low', 'cost']
for x in lst:
    if (x in positive_words):
        print(x)
# Out:
# excellent
# good
